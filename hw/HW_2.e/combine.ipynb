# %% [markdown]
# # Denison DA210/CS181 Homework 2.e - Step 1
#
# Before you turn this problem in, make sure everything runs as expected. This is a combination of **restarting the kernel** and then **running all cells** (in the menubar, select Kernel$\rightarrow$Restart And Run All).
#
# Make sure you fill in any place that says `# YOUR CODE HERE` or "YOUR ANSWER HERE".

# %% [markdown]
# ---

# %%
import os
import os.path
import pandas as pd

datadir = "publicdata"

# %% [markdown]
# ---
#
# ## Part A: Concatenating along the row dimension
#
# **Q1:** In the data directory, you will find two csv files, `educationTop.csv` and `educationBottom.csv`, both based on data hosted by `www.census.gov`.  Both have the same columns, and each row is a U.S. metropolitan area, with data on population, education, and unemployment.  The first `csv` file contains metropolitan areas starting with A-K, and the second starting with L-Z.
#
# Read both into `pandas` data frames `education_top` and `education_bottom`, using the column `GEO.id2` as an index.
#
# Be careful, as these files have **two** lines that might be considered header lines.  The first one is more descriptive, and the second one is more concise and gives succint variable names.  So when we read from the csv, we want to **skip** the first line and then use the second line as the header line.  The `pandas` `read_csv` constructor can do this for you, but you have to discover and use the correct arguments.  (Documentation: https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html)

# %%
filepath1 = os.path.join(datadir, "educationTop.csv")
file1 = pd.read_csv(filepath1, skiprows=[0], index_col = ["GEO.id2"]) 
education_top = pd.DataFrame(file1)

filepath2 = os.path.join(datadir, "educationBottom.csv")
file2 = pd.read_csv(filepath2, skiprows=[0], index_col = ["GEO.id2"]) 
education_bottom = pd.DataFrame(file2)

# %%
# Display a sample of the "top" DataFrame
education_top.head(2)
# Out:
#                  GEO.id       GEO.display-label  HD01_VD01  HD02_VD01  \
# GEO.id2
# 10180    310M100US10180  Abilene, TX Metro Area      82270       1582
# 10420    310M100US10420    Akron, OH Metro Area     369311       1080
#
#          HD01_VD02  HD02_VD02  HD01_VD03  HD02_VD03  HD01_VD04  HD02_VD04  \
# GEO.id2
# 10180        13820       1873       6484       1272          0        206
# 10420        26613       2972      14519       2048          0        182
#
#          ...  HD01_VD25  HD02_VD25  HD01_VD26  HD02_VD26  HD01_VD27  \
# GEO.id2  ...
# 10180    ...        579        347      12909       1564      12770
# 10420    ...         43         70      97693       4241      94492
#
#          HD02_VD27  HD01_VD28  HD02_VD28  HD01_VD29  HD02_VD29
# GEO.id2
# 10180         1557        139        137       3633        826
# 10420         4200       3201        888      13895       1627
#
# [2 rows x 60 columns]

# %%
# Display a sample of the "bottom" DataFrame
education_bottom.head(2)
# Out:
#                  GEO.id            GEO.display-label  HD01_VD01  HD02_VD01  \
# GEO.id2
# 29100    310M100US29100  La Crosse, WI-MN Metro Area      67151        664
# 29140    310M100US29140     Lafayette, IN Metro Area      94481       1352
#
#          HD01_VD02  HD02_VD02  HD01_VD03  HD02_VD03  HD01_VD04  HD02_VD04  \
# GEO.id2
# 29100         2114        654       1202        471          0        184
# 29140         8844       1537       5463       1334          0        184
#
#          ...  HD01_VD25  HD02_VD25  HD01_VD26  HD02_VD26  HD01_VD27  \
# GEO.id2  ...
# 29100    ...          0        184      17955       1585      17592
# 29140    ...         19         31      27825       2372      26749
#
#          HD02_VD27  HD01_VD28  HD02_VD28  HD01_VD29  HD02_VD29
# GEO.id2
# 29100         1565        363        286       2453        659
# 29140         2256       1076        523       4217        948
#
# [2 rows x 60 columns]

# %%
# Testing Cell
assert education_top.shape == (176, 60)
assert education_bottom.shape == (190, 60)
assert education_top.index.name == "GEO.id2"
assert education_bottom.index.name == "GEO.id2"
assert "HD01_VD01" in education_top
assert "HD01_VD01" in education_bottom
assert education_top.iloc[8,2] == 129504
assert education_bottom.iloc[8,4] == 39259

# %% [markdown]
# **Q2:** Concatenate these two data frames along the row dimension (with the top one on top), and call the result `educationDF`.

# %%
educationDF = pd.concat([education_top, education_bottom], axis = 0)

# Display a sample of the DataFrame
educationDF.head(4)
# Out:
#                  GEO.id                       GEO.display-label  HD01_VD01  \
# GEO.id2
# 10180    310M100US10180                  Abilene, TX Metro Area      82270
# 10420    310M100US10420                    Akron, OH Metro Area     369311
# 10500    310M100US10500                   Albany, GA Metro Area      78159
# 10580    310M100US10580  Albany-Schenectady-Troy, NY Metro Area     466236
#
#          HD02_VD01  HD01_VD02  HD02_VD02  HD01_VD03  HD02_VD03  HD01_VD04  \
# GEO.id2
# 10180         1582      13820       1873       6484       1272          0
# 10420         1080      26613       2972      14519       2048          0
# 10500         1072      13689       2238       7681       1645          0
# 10580         1818      29031       3211      16906       2415          0
#
#          HD02_VD04  ...  HD01_VD25  HD02_VD25  HD01_VD26  HD02_VD26  \
# GEO.id2             ...
# 10180          206  ...        579        347      12909       1564
# 10420          182  ...         43         70      97693       4241
# 10500          208  ...        247        249      12051       1611
# 10580          185  ...        572        510     146172       5083
#
#          HD01_VD27  HD02_VD27  HD01_VD28  HD02_VD28  HD01_VD29  HD02_VD29
# GEO.id2
# 10180        12770       1557        139        137       3633        826
# 10420        94492       4200       3201        888      13895       1627
# 10500        11493       1472        558        507       2599        678
# 10580       142431       5036       3741        887      22891       1945
#
# [4 rows x 60 columns]

# %%
# Testing Cell
assert educationDF.shape == (366, 60)
assert educationDF.index.name == "GEO.id2"
assert "HD01_VD01" in educationDF
assert educationDF.iloc[8,2] == 129504
assert educationDF.iloc[184,4] == 39259

# %% [markdown]
# ---
#
# ## Part B: Concatenating along the column dimension
#
# **Q3:** In the data directory, you will find two csv files, `educationLeft.csv` and `educationRight.csv`, both based on data hosted by `www.census.gov`.  Both have the same rows, and each row is a U.S. metropolitan area, with data on population, education, and unemployment.  The first has information on individuals without a college degree, and the second has information on individuals with a college degree.
#
# Read both into `pandas` data frames `education_left` and `education_right`.  The `GEO.display-label` field should serve as the row index.
#
# The same cautions on the CSV having an informational row of headers followed by the header variable names applies to these two CSV files as well.

# %%
filepath3 = os.path.join(datadir, "educationLeft.csv") 
file3 = pd.read_csv(filepath3, skiprows=[0], index_col = ["GEO.display-label"]) 
education_left = pd.DataFrame(file3) 

filepath4 = os.path.join(datadir, "educationRight.csv") 
file4 = pd.read_csv(filepath4, skiprows=[0], index_col = ["GEO.display-label"]) 
education_right = pd.DataFrame(file4)

# %%
# Display a sample of the left DataFrame
education_left.head(2)
# Out:
#         GEO.display-label  HD01_VD01  HD02_VD01  HD01_VD02  HD02_VD02  \
# 0  Abilene, TX Metro Area      82270       1582      13820       1873
# 1    Akron, OH Metro Area     369311       1080      26613       2972
#
#    HD01_VD03  HD02_VD03  HD01_VD04  HD02_VD04  HD01_VD05  ...  HD01_VD11  \
# 0       6484       1272          0        206       6484  ...        242
# 1      14519       2048          0        182      14519  ...          0
#
#    HD02_VD11  HD01_VD12  HD02_VD12  HD01_VD13  HD02_VD13  HD01_VD14  \
# 0        230      16089       2007      15268       2047        821
# 1        182      91228       4194      82462       4125       8766
#
#    HD02_VD14  HD01_VD15  HD02_VD15
# 0        437       8729       1335
# 1       1850      28828       3019
#
# [2 rows x 31 columns]

# %%
# Display a sample of the right DataFrame
education_right.head(2)
# Out:
#                         HD01_VD16  HD02_VD16  HD01_VD17  HD02_VD17  HD01_VD18  \
# GEO.display-label
# Abilene, TX Metro Area      26269       2060      20430       2075        705
# Akron, OH Metro Area       111011       4257      86994       3887        123
#
#                         HD02_VD18  HD01_VD19  HD02_VD19  HD01_VD20  HD02_VD20  \
# GEO.display-label
# Abilene, TX Metro Area        307      19725       1978      18421       1902
# Akron, OH Metro Area          119      86871       3903      79172       3642
#
#                         ...  HD01_VD25  HD02_VD25  HD01_VD26  HD02_VD26  \
# GEO.display-label       ...
# Abilene, TX Metro Area  ...        579        347      12909       1564
# Akron, OH Metro Area    ...         43         70      97693       4241
#
#                         HD01_VD27  HD02_VD27  HD01_VD28  HD02_VD28  HD01_VD29  \
# GEO.display-label
# Abilene, TX Metro Area      12770       1557        139        137       3633
# Akron, OH Metro Area        94492       4200       3201        888      13895
#
#                         HD02_VD29
# GEO.display-label
# Abilene, TX Metro Area        826
# Akron, OH Metro Area         1627
#
# [2 rows x 28 columns]

# %%
# Testing Cell
assert education_left.shape == (366, 30)
assert education_right.shape == (366, 28)
assert education_left.index.name == "GEO.display-label"
assert education_right.index.name == "GEO.display-label"
assert "HD01_VD01" in education_left
assert "HD01_VD01" not in education_right
assert "Abilene, TX Metro Area" in education_left.index
assert "Abilene, TX Metro Area" in education_right.index
assert education_left.iloc[10,3] == 2265
assert education_right.iloc[10,2] == 63125

# %% [markdown]
# **Q4:** Concatenate these two data frames along the column dimension, and call the result `educationDF2`.

# %%
educationDF2 = pd.concat([education_left, education_right], axis =1)

# Display a sample of the DataFrame
educationDF2.head(4)
# Out:
#                                         HD01_VD01  HD02_VD01  HD01_VD02  \
# GEO.display-label
# Abilene, TX Metro Area                      82270       1582      13820
# Akron, OH Metro Area                       369311       1080      26613
# Albany, GA Metro Area                       78159       1072      13689
# Albany-Schenectady-Troy, NY Metro Area     466236       1818      29031
#
#                                         HD02_VD02  HD01_VD03  HD02_VD03  \
# GEO.display-label
# Abilene, TX Metro Area                       1873       6484       1272
# Akron, OH Metro Area                         2972      14519       2048
# Albany, GA Metro Area                        2238       7681       1645
# Albany-Schenectady-Troy, NY Metro Area       3211      16906       2415
#
#                                         HD01_VD04  HD02_VD04  HD01_VD05  \
# GEO.display-label
# Abilene, TX Metro Area                          0        206       6484
# Akron, OH Metro Area                            0        182      14519
# Albany, GA Metro Area                           0        208       7681
# Albany-Schenectady-Troy, NY Metro Area          0        185      16906
#
#                                         HD02_VD05  ...  HD01_VD25  HD02_VD25  \
# GEO.display-label                                  ...
# Abilene, TX Metro Area                       1272  ...        579        347
# Akron, OH Metro Area                         2048  ...         43         70
# Albany, GA Metro Area                        1645  ...        247        249
# Albany-Schenectady-Troy, NY Metro Area       2415  ...        572        510
#
#                                         HD01_VD26  HD02_VD26  HD01_VD27  \
# GEO.display-label
# Abilene, TX Metro Area                      12909       1564      12770
# Akron, OH Metro Area                        97693       4241      94492
# Albany, GA Metro Area                       12051       1611      11493
# Albany-Schenectady-Troy, NY Metro Area     146172       5083     142431
#
#                                         HD02_VD27  HD01_VD28  HD02_VD28  \
# GEO.display-label
# Abilene, TX Metro Area                       1557        139        137
# Akron, OH Metro Area                         4200       3201        888
# Albany, GA Metro Area                        1472        558        507
# Albany-Schenectady-Troy, NY Metro Area       5036       3741        887
#
#                                         HD01_VD29  HD02_VD29
# GEO.display-label
# Abilene, TX Metro Area                       3633        826
# Akron, OH Metro Area                        13895       1627
# Albany, GA Metro Area                        2599        678
# Albany-Schenectady-Troy, NY Metro Area      22891       1945
#
# [4 rows x 58 columns]

# %%
# Testing Cell
assert educationDF2.shape == (366, 58)
assert educationDF2.index.name == "GEO.display-label"
assert "HD01_VD01" in educationDF2
assert educationDF2.iloc[10,3] == 2265
assert educationDF2.iloc[10,32] == 63125

# %% [markdown]
# ---
#
# ## Part C: Joining/merging data frames
#
# **Q5:** In the data directory, you will find two csv files, `educationLeftJ.csv` and `educationRightJ.csv`, both based on data hosted by `www.census.gov`.  In both, rows represent U.S. metropolitan area, with data on population, education, and unemployment.  However, they do not have exactly the same set of rows, and the columns are totally different except for the index column `Geography`.
#
# In these CSV files, there is not an "extra" header line.  The row label index should come from `Geography` unless you are instructed otherwise.
#
# Read both into `pandas` data frames, with names `education_left_j` and `education_right_j`.

# %%
left = os.path.join(datadir, "educationLeftJ.csv")
left = pd.read_csv(left, index_col = ["Geography"]) 
education_left_j = pd.DataFrame(left) 


right = os.path.join(datadir, "educationRightJ.csv")
right = pd.read_csv(right, index_col = ["Geography"]) 
education_right_j = pd.DataFrame(right)

# %%
# Display a sample of the left_j DataFrame
education_left_j.head(2)
# Out:
#                         Estimate; Less than high school graduate: - In labor force:  \
# Geography
# Abilene, TX Metro Area                                               6484
# Akron, OH Metro Area                                                14519
#
#                         Estimate; Less than high school graduate: - In labor force: - In Armed Forces  \
# Geography
# Abilene, TX Metro Area                                                  0
# Akron, OH Metro Area                                                    0
#
#                         Estimate; Less than high school graduate: - In labor force: - Civilian:  \
# Geography
# Abilene, TX Metro Area                                               6484
# Akron, OH Metro Area                                                14519
#
#                         Estimate; Less than high school graduate: - In labor force: - Civilian: - Employed  \
# Geography
# Abilene, TX Metro Area                                               5347
# Akron, OH Metro Area                                                11338
#
#                         Estimate; Less than high school graduate: - In labor force: - Civilian: - Unemployed  \
# Geography
# Abilene, TX Metro Area                                               1137
# Akron, OH Metro Area                                                 3181
#
#                         Estimate; Less than high school graduate: - Not in labor force  \
# Geography
# Abilene, TX Metro Area                                               7336
# Akron, OH Metro Area                                                12094
#
#                         Estimate; High school graduate: - In labor force:  \
# Geography
# Abilene, TX Metro Area                                              16331
# Akron, OH Metro Area                                                91228
#
#                         Estimate; High school graduate: - In labor force: - In Armed Forces  \
# Geography
# Abilene, TX Metro Area                                                242
# Akron, OH Metro Area                                                    0
#
#                         Estimate; High school graduate: - In labor force: - Civilian:  \
# Geography
# Abilene, TX Metro Area                                              16089
# Akron, OH Metro Area                                                91228
#
#                         Estimate; High school graduate: - In labor force: - Civilian: - Employed  \
# Geography
# Abilene, TX Metro Area                                              15268
# Akron, OH Metro Area                                                82462
#
#                         Estimate; High school graduate: - In labor force: - Civilian: - Unemployed  \
# Geography
# Abilene, TX Metro Area                                                821
# Akron, OH Metro Area                                                 8766
#
#                         Estimate; High school graduate: - Not in labor force
# Geography
# Abilene, TX Metro Area                                               8729
# Akron, OH Metro Area                                                28828

# %%
# Display a sample of the right_j DataFrame
education_right_j.head(2)
# Out:
#                         Estimate; Some college or associate's degree: - In labor force:  \
# Geography
# Abilene, TX Metro Area                                              20430
# Akron, OH Metro Area                                                86994
#
#                         Estimate; Some college or associate's degree: - In labor force: - In Armed Forces  \
# Geography
# Abilene, TX Metro Area                                                705
# Akron, OH Metro Area                                                  123
#
#                         Estimate; Some college or associate's degree: - In labor force: - Civilian:  \
# Geography
# Abilene, TX Metro Area                                              19725
# Akron, OH Metro Area                                                86871
#
#                         Estimate; Some college or associate's degree: - In labor force: - Civilian: - Employed  \
# Geography
# Abilene, TX Metro Area                                              18421
# Akron, OH Metro Area                                                79172
#
#                         Estimate; Some college or associate's degree: - In labor force: - Civilian: - Unemployed  \
# Geography
# Abilene, TX Metro Area                                               1304
# Akron, OH Metro Area                                                 7699
#
#                         Estimate; Some college or associate's degree: - Not in labor force  \
# Geography
# Abilene, TX Metro Area                                               5839
# Akron, OH Metro Area                                                24017
#
#                         Estimate; Bachelor's degree or higher: - In labor force:  \
# Geography
# Abilene, TX Metro Area                                              13488
# Akron, OH Metro Area                                                97736
#
#                         Estimate; Bachelor's degree or higher: - In labor force: - In Armed Forces  \
# Geography
# Abilene, TX Metro Area                                                579
# Akron, OH Metro Area                                                   43
#
#                         Estimate; Bachelor's degree or higher: - In labor force: - Civilian:  \
# Geography
# Abilene, TX Metro Area                                              12909
# Akron, OH Metro Area                                                97693
#
#                         Estimate; Bachelor's degree or higher: - In labor force: - Civilian: - Employed  \
# Geography
# Abilene, TX Metro Area                                              12770
# Akron, OH Metro Area                                                94492
#
#                         Estimate; Bachelor's degree or higher: - In labor force: - Civilian: - Unemployed  \
# Geography
# Abilene, TX Metro Area                                                139
# Akron, OH Metro Area                                                 3201
#
#                         Estimate; Bachelor's degree or higher: - Not in labor force
# Geography
# Abilene, TX Metro Area                                               3633
# Akron, OH Metro Area                                                13895

# %%
# Testing Cell
assert education_left_j.shape == (249, 12)
assert education_right_j.shape == (215, 12)
assert education_left_j.index.name == "Geography"
assert education_right_j.index.name == "Geography"
assert "Estimate; Less than high school graduate: - In labor force: - Civilian: - Unemployed" in education_left_j
assert "Estimate; Less than high school graduate: - In labor force: - Civilian: - Unemployed" not in education_right_j
assert "Estimate; Bachelor's degree or higher: - In labor force:" not in education_left_j
assert "Estimate; Bachelor's degree or higher: - In labor force:" in education_right_j
assert "Battle Creek, MI Metro Area" in education_left_j.index
assert "Battle Creek, MI Metro Area" not in education_right_j.index
assert "Bridgeport-Stamford-Norwalk, CT Metro Area" not in education_left_j.index
assert "Bridgeport-Stamford-Norwalk, CT Metro Area" in education_right_j.index
assert education_left_j.iloc[5,6] == 38994
assert education_right_j.iloc[9,2] == 59784

# %% [markdown]
# **Q6:** Make a copy of `education_left_j` called `education_left_orig`.  Starting with `education_left_j`, do a left join to bring in the data from `education_right_j`, storing your answer as `df_j1`.

# %%
education_left_orig = education_left_j.copy()

df_j1 = education_left_orig.join(education_right_j, how ="left")

# Display a sample of the joined DataFrame
df_j1.head(2)
# Out:
#                                               Estimate; Less than high school graduate: - In labor force:  \
# Geography
# Abilene, TX Metro Area                                                                     6484
# Akron, OH Metro Area                                                                      14519
# Albany, GA Metro Area                                                                      7681
# Albany-Schenectady-Troy, NY Metro Area                                                    16906
# Albuquerque, NM Metro Area                                                                30718
# ...                                                                                         ...
# Worcester, MA Metro Area                                                                  17925
# Yakima, WA Metro Area                                                                     24148
# York-Hanover, PA Metro Area                                                               14583
# Youngstown-Warren-Boardman, OH-PA Metro Area                                              13440
# Yuma, AZ Metro Area                                                                       15284
#
#                                               Estimate; Less than high school graduate: - In labor force: - In Armed Forces  \
# Geography
# Abilene, TX Metro Area                                                                        0
# Akron, OH Metro Area                                                                          0
# Albany, GA Metro Area                                                                         0
# Albany-Schenectady-Troy, NY Metro Area                                                        0
# Albuquerque, NM Metro Area                                                                    0
# ...                                                                                         ...
# Worcester, MA Metro Area                                                                      0
# Yakima, WA Metro Area                                                                         0
# York-Hanover, PA Metro Area                                                                   0
# Youngstown-Warren-Boardman, OH-PA Metro Area                                                  0
# Yuma, AZ Metro Area                                                                           0
#
#                                               Estimate; Less than high school graduate: - In labor force: - Civilian:  \
# Geography
# Abilene, TX Metro Area                                                                     6484
# Akron, OH Metro Area                                                                      14519
# Albany, GA Metro Area                                                                      7681
# Albany-Schenectady-Troy, NY Metro Area                                                    16906
# Albuquerque, NM Metro Area                                                                30718
# ...                                                                                         ...
# Worcester, MA Metro Area                                                                  17925
# Yakima, WA Metro Area                                                                     24148
# York-Hanover, PA Metro Area                                                               14583
# Youngstown-Warren-Boardman, OH-PA Metro Area                                              13440
# Yuma, AZ Metro Area                                                                       15284
#
#                                               Estimate; Less than high school graduate: - In labor force: - Civilian: - Employed  \
# Geography
# Abilene, TX Metro Area                                                                     5347
# Akron, OH Metro Area                                                                      11338
# Albany, GA Metro Area                                                                      6202
# Albany-Schenectady-Troy, NY Metro Area                                                    13148
# Albuquerque, NM Metro Area                                                                26588
# ...                                                                                         ...
# Worcester, MA Metro Area                                                                  14961
# Yakima, WA Metro Area                                                                     21053
# York-Hanover, PA Metro Area                                                               12097
# Youngstown-Warren-Boardman, OH-PA Metro Area                                              11609
# Yuma, AZ Metro Area                                                                       12140
#
#                                               Estimate; Less than high school graduate: - In labor force: - Civilian: - Unemployed  \
# Geography
# Abilene, TX Metro Area                                                                     1137
# Akron, OH Metro Area                                                                       3181
# Albany, GA Metro Area                                                                      1479
# Albany-Schenectady-Troy, NY Metro Area                                                     3758
# Albuquerque, NM Metro Area                                                                 4130
# ...                                                                                         ...
# Worcester, MA Metro Area                                                                   2964
# Yakima, WA Metro Area                                                                      3095
# York-Hanover, PA Metro Area                                                                2486
# Youngstown-Warren-Boardman, OH-PA Metro Area                                               1831
# Yuma, AZ Metro Area                                                                        3144
#
#                                               Estimate; Less than high school graduate: - Not in labor force  \
# Geography
# Abilene, TX Metro Area                                                                     7336
# Akron, OH Metro Area                                                                      12094
# Albany, GA Metro Area                                                                      6008
# Albany-Schenectady-Troy, NY Metro Area                                                    12125
# Albuquerque, NM Metro Area                                                                20720
# ...                                                                                         ...
# Worcester, MA Metro Area                                                                  16620
# Yakima, WA Metro Area                                                                      9982
# York-Hanover, PA Metro Area                                                                7403
# Youngstown-Warren-Boardman, OH-PA Metro Area                                              12562
# Yuma, AZ Metro Area                                                                        9089
#
#                                               Estimate; High school graduate: - In labor force:  \
# Geography
# Abilene, TX Metro Area                                                                    16331
# Akron, OH Metro Area                                                                      91228
# Albany, GA Metro Area                                                                     14339
# Albany-Schenectady-Troy, NY Metro Area                                                    87217
# Albuquerque, NM Metro Area                                                                83536
# ...                                                                                         ...
# Worcester, MA Metro Area                                                                  90973
# Yakima, WA Metro Area                                                                     21566
# York-Hanover, PA Metro Area                                                               72949
# Youngstown-Warren-Boardman, OH-PA Metro Area                                              78959
# Yuma, AZ Metro Area                                                                       12348
#
#                                               Estimate; High school graduate: - In labor force: - In Armed Forces  \
# Geography
# Abilene, TX Metro Area                                                                      242
# Akron, OH Metro Area                                                                          0
# Albany, GA Metro Area                                                                        28
# Albany-Schenectady-Troy, NY Metro Area                                                      172
# Albuquerque, NM Metro Area                                                                  172
# ...                                                                                         ...
# Worcester, MA Metro Area                                                                      0
# Yakima, WA Metro Area                                                                         0
# York-Hanover, PA Metro Area                                                                  87
# Youngstown-Warren-Boardman, OH-PA Metro Area                                                  0
# Yuma, AZ Metro Area                                                                         329
#
#                                               Estimate; High school graduate: - In labor force: - Civilian:  \
# Geography
# Abilene, TX Metro Area                                                                    16089
# Akron, OH Metro Area                                                                      91228
# Albany, GA Metro Area                                                                     14311
# Albany-Schenectady-Troy, NY Metro Area                                                    87045
# Albuquerque, NM Metro Area                                                                83364
# ...                                                                                         ...
# Worcester, MA Metro Area                                                                  90973
# Yakima, WA Metro Area                                                                     21566
# York-Hanover, PA Metro Area                                                               72862
# Youngstown-Warren-Boardman, OH-PA Metro Area                                              78959
# Yuma, AZ Metro Area                                                                       12019
#
#                                               Estimate; High school graduate: - In labor force: - Civilian: - Employed  \
# Geography
# Abilene, TX Metro Area                                                                    15268
# Akron, OH Metro Area                                                                      82462
# Albany, GA Metro Area                                                                     12724
# Albany-Schenectady-Troy, NY Metro Area                                                    79712
# Albuquerque, NM Metro Area                                                                75155
# ...                                                                                         ...
# Worcester, MA Metro Area                                                                  80798
# Yakima, WA Metro Area                                                                     20002
# York-Hanover, PA Metro Area                                                               67038
# Youngstown-Warren-Boardman, OH-PA Metro Area                                              72385
# Yuma, AZ Metro Area                                                                       10779
#
#                                               ...  \
# Geography                                     ...
# Abilene, TX Metro Area                        ...
# Akron, OH Metro Area                          ...
# Albany, GA Metro Area                         ...
# Albany-Schenectady-Troy, NY Metro Area        ...
# Albuquerque, NM Metro Area                    ...
# ...                                           ...
# Worcester, MA Metro Area                      ...
# Yakima, WA Metro Area                         ...
# York-Hanover, PA Metro Area                   ...
# Youngstown-Warren-Boardman, OH-PA Metro Area  ...
# Yuma, AZ Metro Area                           ...
#
#                                               Estimate; Some college or associate's degree: - In labor force: - Civilian:  \
# Geography
# Abilene, TX Metro Area                                                                  19725.0
# Akron, OH Metro Area                                                                    86871.0
# Albany, GA Metro Area                                                                   21194.0
# Albany-Schenectady-Troy, NY Metro Area                                                 126002.0
# Albuquerque, NM Metro Area                                                             121720.0
# ...                                                                                         ...
# Worcester, MA Metro Area                                                                    NaN
# Yakima, WA Metro Area                                                                       NaN
# York-Hanover, PA Metro Area                                                                 NaN
# Youngstown-Warren-Boardman, OH-PA Metro Area                                                NaN
# Yuma, AZ Metro Area                                                                     23628.0
#
#                                               Estimate; Some college or associate's degree: - In labor force: - Civilian: - Employed  \
# Geography
# Abilene, TX Metro Area                                                                  18421.0
# Akron, OH Metro Area                                                                    79172.0
# Albany, GA Metro Area                                                                   18370.0
# Albany-Schenectady-Troy, NY Metro Area                                                 117400.0
# Albuquerque, NM Metro Area                                                             113275.0
# ...                                                                                         ...
# Worcester, MA Metro Area                                                                    NaN
# Yakima, WA Metro Area                                                                       NaN
# York-Hanover, PA Metro Area                                                                 NaN
# Youngstown-Warren-Boardman, OH-PA Metro Area                                                NaN
# Yuma, AZ Metro Area                                                                     21204.0
#
#                                               Estimate; Some college or associate's degree: - In labor force: - Civilian: - Unemployed  \
# Geography
# Abilene, TX Metro Area                                                                   1304.0
# Akron, OH Metro Area                                                                     7699.0
# Albany, GA Metro Area                                                                    2824.0
# Albany-Schenectady-Troy, NY Metro Area                                                   8602.0
# Albuquerque, NM Metro Area                                                               8445.0
# ...                                                                                         ...
# Worcester, MA Metro Area                                                                    NaN
# Yakima, WA Metro Area                                                                       NaN
# York-Hanover, PA Metro Area                                                                 NaN
# Youngstown-Warren-Boardman, OH-PA Metro Area                                                NaN
# Yuma, AZ Metro Area                                                                      2424.0
#
#                                               Estimate; Some college or associate's degree: - Not in labor force  \
# Geography
# Abilene, TX Metro Area                                                                   5839.0
# Akron, OH Metro Area                                                                    24017.0
# Albany, GA Metro Area                                                                    6520.0
# Albany-Schenectady-Troy, NY Metro Area                                                  24532.0
# Albuquerque, NM Metro Area                                                              42564.0
# ...                                                                                         ...
# Worcester, MA Metro Area                                                                    NaN
# Yakima, WA Metro Area                                                                       NaN
# York-Hanover, PA Metro Area                                                                 NaN
# Youngstown-Warren-Boardman, OH-PA Metro Area                                                NaN
# Yuma, AZ Metro Area                                                                      7634.0
#
#                                               Estimate; Bachelor's degree or higher: - In labor force:  \
# Geography
# Abilene, TX Metro Area                                                                  13488.0
# Akron, OH Metro Area                                                                    97736.0
# Albany, GA Metro Area                                                                   12298.0
# Albany-Schenectady-Troy, NY Metro Area                                                 146744.0
# Albuquerque, NM Metro Area                                                             120155.0
# ...                                                                                         ...
# Worcester, MA Metro Area                                                                    NaN
# Yakima, WA Metro Area                                                                       NaN
# York-Hanover, PA Metro Area                                                                 NaN
# Youngstown-Warren-Boardman, OH-PA Metro Area                                                NaN
# Yuma, AZ Metro Area                                                                     11399.0
#
#                                               Estimate; Bachelor's degree or higher: - In labor force: - In Armed Forces  \
# Geography
# Abilene, TX Metro Area                                                                    579.0
# Akron, OH Metro Area                                                                       43.0
# Albany, GA Metro Area                                                                     247.0
# Albany-Schenectady-Troy, NY Metro Area                                                    572.0
# Albuquerque, NM Metro Area                                                               1179.0
# ...                                                                                         ...
# Worcester, MA Metro Area                                                                    NaN
# Yakima, WA Metro Area                                                                       NaN
# York-Hanover, PA Metro Area                                                                 NaN
# Youngstown-Warren-Boardman, OH-PA Metro Area                                                NaN
# Yuma, AZ Metro Area                                                                       728.0
#
#                                               Estimate; Bachelor's degree or higher: - In labor force: - Civilian:  \
# Geography
# Abilene, TX Metro Area                                                                  12909.0
# Akron, OH Metro Area                                                                    97693.0
# Albany, GA Metro Area                                                                   12051.0
# Albany-Schenectady-Troy, NY Metro Area                                                 146172.0
# Albuquerque, NM Metro Area                                                             118976.0
# ...                                                                                         ...
# Worcester, MA Metro Area                                                                    NaN
# Yakima, WA Metro Area                                                                       NaN
# York-Hanover, PA Metro Area                                                                 NaN
# Youngstown-Warren-Boardman, OH-PA Metro Area                                                NaN
# Yuma, AZ Metro Area                                                                     10671.0
#
#                                               Estimate; Bachelor's degree or higher: - In labor force: - Civilian: - Employed  \
# Geography
# Abilene, TX Metro Area                                                                  12770.0
# Akron, OH Metro Area                                                                    94492.0
# Albany, GA Metro Area                                                                   11493.0
# Albany-Schenectady-Troy, NY Metro Area                                                 142431.0
# Albuquerque, NM Metro Area                                                             114318.0
# ...                                                                                         ...
# Worcester, MA Metro Area                                                                    NaN
# Yakima, WA Metro Area                                                                       NaN
# York-Hanover, PA Metro Area                                                                 NaN
# Youngstown-Warren-Boardman, OH-PA Metro Area                                                NaN
# Yuma, AZ Metro Area                                                                     10029.0
#
#                                               Estimate; Bachelor's degree or higher: - In labor force: - Civilian: - Unemployed  \
# Geography
# Abilene, TX Metro Area                                                                    139.0
# Akron, OH Metro Area                                                                     3201.0
# Albany, GA Metro Area                                                                     558.0
# Albany-Schenectady-Troy, NY Metro Area                                                   3741.0
# Albuquerque, NM Metro Area                                                               4658.0
# ...                                                                                         ...
# Worcester, MA Metro Area                                                                    NaN
# Yakima, WA Metro Area                                                                       NaN
# York-Hanover, PA Metro Area                                                                 NaN
# Youngstown-Warren-Boardman, OH-PA Metro Area                                                NaN
# Yuma, AZ Metro Area                                                                       642.0
#
#                                               Estimate; Bachelor's degree or higher: - Not in labor force
# Geography
# Abilene, TX Metro Area                                                                   3633.0
# Akron, OH Metro Area                                                                    13895.0
# Albany, GA Metro Area                                                                    2599.0
# Albany-Schenectady-Troy, NY Metro Area                                                  22891.0
# Albuquerque, NM Metro Area                                                              21356.0
# ...                                                                                         ...
# Worcester, MA Metro Area                                                                    NaN
# Yakima, WA Metro Area                                                                       NaN
# York-Hanover, PA Metro Area                                                                 NaN
# Youngstown-Warren-Boardman, OH-PA Metro Area                                                NaN
# Yuma, AZ Metro Area                                                                      2188.0
#
# [249 rows x 24 columns]

# %%
# Testing Cell
assert education_left_orig.shape == (249, 12)

assert df_j1.shape == (249, 24)
assert df_j1.index.name == "Geography"
assert "Estimate; Less than high school graduate: - In labor force: - Civilian: - Unemployed" in df_j1
assert "Estimate; Bachelor's degree or higher: - In labor force:" in df_j1
assert "Battle Creek, MI Metro Area" in df_j1.index
assert "Bridgeport-Stamford-Norwalk, CT Metro Area" not in df_j1.index
assert df_j1.iloc[5,6] == 38994
assert df_j1.iloc[5,14] == 59784

# %% [markdown]
# **Q7:** Starting with `education_left_orig`, do an inner join to bring in the data from `education_right_j`, storing your answer as `df_j2`.

# %%
df_j2 = education_left_orig.join( education_right_j, how = "inner")
# Display a sample of the joined DataFrame
df_j2.head(2)
# Out:
#                                          Estimate; Less than high school graduate: - In labor force:  \
# Geography
# Abilene, TX Metro Area                                                                6484
# Akron, OH Metro Area                                                                 14519
# Albany, GA Metro Area                                                                 7681
# Albany-Schenectady-Troy, NY Metro Area                                               16906
# Albuquerque, NM Metro Area                                                           30718
# ...                                                                                    ...
# Wenatchee-East Wenatchee, WA Metro Area                                               7258
# Wheeling, WV-OH Metro Area                                                            3902
# Wichita, KS Metro Area                                                               19870
# Wichita Falls, TX Metro Area                                                          3875
# Yuma, AZ Metro Area                                                                  15284
#
#                                          Estimate; Less than high school graduate: - In labor force: - In Armed Forces  \
# Geography
# Abilene, TX Metro Area                                                                   0
# Akron, OH Metro Area                                                                     0
# Albany, GA Metro Area                                                                    0
# Albany-Schenectady-Troy, NY Metro Area                                                   0
# Albuquerque, NM Metro Area                                                               0
# ...                                                                                    ...
# Wenatchee-East Wenatchee, WA Metro Area                                                  0
# Wheeling, WV-OH Metro Area                                                               0
# Wichita, KS Metro Area                                                                   0
# Wichita Falls, TX Metro Area                                                             0
# Yuma, AZ Metro Area                                                                      0
#
#                                          Estimate; Less than high school graduate: - In labor force: - Civilian:  \
# Geography
# Abilene, TX Metro Area                                                                6484
# Akron, OH Metro Area                                                                 14519
# Albany, GA Metro Area                                                                 7681
# Albany-Schenectady-Troy, NY Metro Area                                               16906
# Albuquerque, NM Metro Area                                                           30718
# ...                                                                                    ...
# Wenatchee-East Wenatchee, WA Metro Area                                               7258
# Wheeling, WV-OH Metro Area                                                            3902
# Wichita, KS Metro Area                                                               19870
# Wichita Falls, TX Metro Area                                                          3875
# Yuma, AZ Metro Area                                                                  15284
#
#                                          Estimate; Less than high school graduate: - In labor force: - Civilian: - Employed  \
# Geography
# Abilene, TX Metro Area                                                                5347
# Akron, OH Metro Area                                                                 11338
# Albany, GA Metro Area                                                                 6202
# Albany-Schenectady-Troy, NY Metro Area                                               13148
# Albuquerque, NM Metro Area                                                           26588
# ...                                                                                    ...
# Wenatchee-East Wenatchee, WA Metro Area                                               6528
# Wheeling, WV-OH Metro Area                                                            3709
# Wichita, KS Metro Area                                                               18200
# Wichita Falls, TX Metro Area                                                          3521
# Yuma, AZ Metro Area                                                                  12140
#
#                                          Estimate; Less than high school graduate: - In labor force: - Civilian: - Unemployed  \
# Geography
# Abilene, TX Metro Area                                                                1137
# Akron, OH Metro Area                                                                  3181
# Albany, GA Metro Area                                                                 1479
# Albany-Schenectady-Troy, NY Metro Area                                                3758
# Albuquerque, NM Metro Area                                                            4130
# ...                                                                                    ...
# Wenatchee-East Wenatchee, WA Metro Area                                                730
# Wheeling, WV-OH Metro Area                                                             193
# Wichita, KS Metro Area                                                                1670
# Wichita Falls, TX Metro Area                                                           354
# Yuma, AZ Metro Area                                                                   3144
#
#                                          Estimate; Less than high school graduate: - Not in labor force  \
# Geography
# Abilene, TX Metro Area                                                                7336
# Akron, OH Metro Area                                                                 12094
# Albany, GA Metro Area                                                                 6008
# Albany-Schenectady-Troy, NY Metro Area                                               12125
# Albuquerque, NM Metro Area                                                           20720
# ...                                                                                    ...
# Wenatchee-East Wenatchee, WA Metro Area                                               2734
# Wheeling, WV-OH Metro Area                                                            3530
# Wichita, KS Metro Area                                                               10477
# Wichita Falls, TX Metro Area                                                          4121
# Yuma, AZ Metro Area                                                                   9089
#
#                                          Estimate; High school graduate: - In labor force:  \
# Geography
# Abilene, TX Metro Area                                                               16331
# Akron, OH Metro Area                                                                 91228
# Albany, GA Metro Area                                                                14339
# Albany-Schenectady-Troy, NY Metro Area                                               87217
# Albuquerque, NM Metro Area                                                           83536
# ...                                                                                    ...
# Wenatchee-East Wenatchee, WA Metro Area                                              11225
# Wheeling, WV-OH Metro Area                                                           20559
# Wichita, KS Metro Area                                                               60779
# Wichita Falls, TX Metro Area                                                         17227
# Yuma, AZ Metro Area                                                                  12348
#
#                                          Estimate; High school graduate: - In labor force: - In Armed Forces  \
# Geography
# Abilene, TX Metro Area                                                                 242
# Akron, OH Metro Area                                                                     0
# Albany, GA Metro Area                                                                   28
# Albany-Schenectady-Troy, NY Metro Area                                                 172
# Albuquerque, NM Metro Area                                                             172
# ...                                                                                    ...
# Wenatchee-East Wenatchee, WA Metro Area                                                  0
# Wheeling, WV-OH Metro Area                                                               0
# Wichita, KS Metro Area                                                                 246
# Wichita Falls, TX Metro Area                                                            98
# Yuma, AZ Metro Area                                                                    329
#
#                                          Estimate; High school graduate: - In labor force: - Civilian:  \
# Geography
# Abilene, TX Metro Area                                                               16089
# Akron, OH Metro Area                                                                 91228
# Albany, GA Metro Area                                                                14311
# Albany-Schenectady-Troy, NY Metro Area                                               87045
# Albuquerque, NM Metro Area                                                           83364
# ...                                                                                    ...
# Wenatchee-East Wenatchee, WA Metro Area                                              11225
# Wheeling, WV-OH Metro Area                                                           20559
# Wichita, KS Metro Area                                                               60533
# Wichita Falls, TX Metro Area                                                         17129
# Yuma, AZ Metro Area                                                                  12019
#
#                                          Estimate; High school graduate: - In labor force: - Civilian: - Employed  \
# Geography
# Abilene, TX Metro Area                                                               15268
# Akron, OH Metro Area                                                                 82462
# Albany, GA Metro Area                                                                12724
# Albany-Schenectady-Troy, NY Metro Area                                               79712
# Albuquerque, NM Metro Area                                                           75155
# ...                                                                                    ...
# Wenatchee-East Wenatchee, WA Metro Area                                              10019
# Wheeling, WV-OH Metro Area                                                           18908
# Wichita, KS Metro Area                                                               54823
# Wichita Falls, TX Metro Area                                                         16503
# Yuma, AZ Metro Area                                                                  10779
#
#                                          ...  \
# Geography                                ...
# Abilene, TX Metro Area                   ...
# Akron, OH Metro Area                     ...
# Albany, GA Metro Area                    ...
# Albany-Schenectady-Troy, NY Metro Area   ...
# Albuquerque, NM Metro Area               ...
# ...                                      ...
# Wenatchee-East Wenatchee, WA Metro Area  ...
# Wheeling, WV-OH Metro Area               ...
# Wichita, KS Metro Area                   ...
# Wichita Falls, TX Metro Area             ...
# Yuma, AZ Metro Area                      ...
#
#                                          Estimate; Some college or associate's degree: - In labor force: - Civilian:  \
# Geography
# Abilene, TX Metro Area                                                               19725
# Akron, OH Metro Area                                                                 86871
# Albany, GA Metro Area                                                                21194
# Albany-Schenectady-Troy, NY Metro Area                                              126002
# Albuquerque, NM Metro Area                                                          121720
# ...                                                                                    ...
# Wenatchee-East Wenatchee, WA Metro Area                                              13407
# Wheeling, WV-OH Metro Area                                                           19684
# Wichita, KS Metro Area                                                               90435
# Wichita Falls, TX Metro Area                                                         20619
# Yuma, AZ Metro Area                                                                  23628
#
#                                          Estimate; Some college or associate's degree: - In labor force: - Civilian: - Employed  \
# Geography
# Abilene, TX Metro Area                                                               18421
# Akron, OH Metro Area                                                                 79172
# Albany, GA Metro Area                                                                18370
# Albany-Schenectady-Troy, NY Metro Area                                              117400
# Albuquerque, NM Metro Area                                                          113275
# ...                                                                                    ...
# Wenatchee-East Wenatchee, WA Metro Area                                              12470
# Wheeling, WV-OH Metro Area                                                           17893
# Wichita, KS Metro Area                                                               85130
# Wichita Falls, TX Metro Area                                                         19652
# Yuma, AZ Metro Area                                                                  21204
#
#                                          Estimate; Some college or associate's degree: - In labor force: - Civilian: - Unemployed  \
# Geography
# Abilene, TX Metro Area                                                                1304
# Akron, OH Metro Area                                                                  7699
# Albany, GA Metro Area                                                                 2824
# Albany-Schenectady-Troy, NY Metro Area                                                8602
# Albuquerque, NM Metro Area                                                            8445
# ...                                                                                    ...
# Wenatchee-East Wenatchee, WA Metro Area                                                937
# Wheeling, WV-OH Metro Area                                                            1791
# Wichita, KS Metro Area                                                                5305
# Wichita Falls, TX Metro Area                                                           967
# Yuma, AZ Metro Area                                                                   2424
#
#                                          Estimate; Some college or associate's degree: - Not in labor force  \
# Geography
# Abilene, TX Metro Area                                                                5839
# Akron, OH Metro Area                                                                 24017
# Albany, GA Metro Area                                                                 6520
# Albany-Schenectady-Troy, NY Metro Area                                               24532
# Albuquerque, NM Metro Area                                                           42564
# ...                                                                                    ...
# Wenatchee-East Wenatchee, WA Metro Area                                               5198
# Wheeling, WV-OH Metro Area                                                            5719
# Wichita, KS Metro Area                                                               22581
# Wichita Falls, TX Metro Area                                                          5515
# Yuma, AZ Metro Area                                                                   7634
#
#                                          Estimate; Bachelor's degree or higher: - In labor force:  \
# Geography
# Abilene, TX Metro Area                                                               13488
# Akron, OH Metro Area                                                                 97736
# Albany, GA Metro Area                                                                12298
# Albany-Schenectady-Troy, NY Metro Area                                              146744
# Albuquerque, NM Metro Area                                                          120155
# ...                                                                                    ...
# Wenatchee-East Wenatchee, WA Metro Area                                              10875
# Wheeling, WV-OH Metro Area                                                           13860
# Wichita, KS Metro Area                                                               82555
# Wichita Falls, TX Metro Area                                                         13746
# Yuma, AZ Metro Area                                                                  11399
#
#                                          Estimate; Bachelor's degree or higher: - In labor force: - In Armed Forces  \
# Geography
# Abilene, TX Metro Area                                                                 579
# Akron, OH Metro Area                                                                    43
# Albany, GA Metro Area                                                                  247
# Albany-Schenectady-Troy, NY Metro Area                                                 572
# Albuquerque, NM Metro Area                                                            1179
# ...                                                                                    ...
# Wenatchee-East Wenatchee, WA Metro Area                                                  0
# Wheeling, WV-OH Metro Area                                                               0
# Wichita, KS Metro Area                                                                 624
# Wichita Falls, TX Metro Area                                                           855
# Yuma, AZ Metro Area                                                                    728
#
#                                          Estimate; Bachelor's degree or higher: - In labor force: - Civilian:  \
# Geography
# Abilene, TX Metro Area                                                               12909
# Akron, OH Metro Area                                                                 97693
# Albany, GA Metro Area                                                                12051
# Albany-Schenectady-Troy, NY Metro Area                                              146172
# Albuquerque, NM Metro Area                                                          118976
# ...                                                                                    ...
# Wenatchee-East Wenatchee, WA Metro Area                                              10875
# Wheeling, WV-OH Metro Area                                                           13860
# Wichita, KS Metro Area                                                               81931
# Wichita Falls, TX Metro Area                                                         12891
# Yuma, AZ Metro Area                                                                  10671
#
#                                          Estimate; Bachelor's degree or higher: - In labor force: - Civilian: - Employed  \
# Geography
# Abilene, TX Metro Area                                                               12770
# Akron, OH Metro Area                                                                 94492
# Albany, GA Metro Area                                                                11493
# Albany-Schenectady-Troy, NY Metro Area                                              142431
# Albuquerque, NM Metro Area                                                          114318
# ...                                                                                    ...
# Wenatchee-East Wenatchee, WA Metro Area                                              10595
# Wheeling, WV-OH Metro Area                                                           13374
# Wichita, KS Metro Area                                                               79819
# Wichita Falls, TX Metro Area                                                         12630
# Yuma, AZ Metro Area                                                                  10029
#
#                                          Estimate; Bachelor's degree or higher: - In labor force: - Civilian: - Unemployed  \
# Geography
# Abilene, TX Metro Area                                                                 139
# Akron, OH Metro Area                                                                  3201
# Albany, GA Metro Area                                                                  558
# Albany-Schenectady-Troy, NY Metro Area                                                3741
# Albuquerque, NM Metro Area                                                            4658
# ...                                                                                    ...
# Wenatchee-East Wenatchee, WA Metro Area                                                280
# Wheeling, WV-OH Metro Area                                                             486
# Wichita, KS Metro Area                                                                2112
# Wichita Falls, TX Metro Area                                                           261
# Yuma, AZ Metro Area                                                                    642
#
#                                          Estimate; Bachelor's degree or higher: - Not in labor force
# Geography
# Abilene, TX Metro Area                                                                3633
# Akron, OH Metro Area                                                                 13895
# Albany, GA Metro Area                                                                 2599
# Albany-Schenectady-Troy, NY Metro Area                                               22891
# Albuquerque, NM Metro Area                                                           21356
# ...                                                                                    ...
# Wenatchee-East Wenatchee, WA Metro Area                                               1524
# Wheeling, WV-OH Metro Area                                                            1971
# Wichita, KS Metro Area                                                               12281
# Wichita Falls, TX Metro Area                                                          1938
# Yuma, AZ Metro Area                                                                   2188
#
# [152 rows x 24 columns]

# %%
# Testing Cell
assert df_j2.shape == (152, 24)
assert df_j2.index.name == "Geography"
assert "Estimate; Less than high school graduate: - In labor force: - Civilian: - Unemployed" in df_j2
assert "Estimate; Bachelor's degree or higher: - In labor force:" in df_j2
assert "Battle Creek, MI Metro Area" not in df_j2.index
assert "Bridgeport-Stamford-Norwalk, CT Metro Area" not in df_j2.index
assert "Asheville, NC Metro Area" in df_j2.index
assert df_j2.iloc[5,6] == 38994
assert df_j2.iloc[5,14] == 59784

# %% [markdown]
# **Q8:** We can "merge" two data frames if they do not have a meaningful index, but do share a column name.  You can use this syntax:
#
# ```
#     merged_df = pd.merge(df1, df2, on=<colname>, how=<merge_type>)
# ```
#
# where `<colname>` is the name of the column they share (typically a string), and `<merge_type>` is a string like `"left"`, `"inner"`, etc.
#
# Now read the original csv files in as `edu_left` and `edu_right` with no meaningful index. Then, starting from `edu_left`, do an inner merge along the column `Geography`, storing your answer as `df_j3`.

# %%
left = os.path.join(datadir, "educationLeftJ.csv")
edu_left = pd.DataFrame(pd.read_csv(left))
right = os.path.join(datadir, "educationRightJ.csv")
edu_right = pd.DataFrame(pd.read_csv(right))

df_j3 = pd.merge(edu_left, edu_right, on = "Geography", how = "inner")

# Display a sample of the merged DataFrame
df_j3.head(2)
# Out:
#                 Geography  \
# 0  Abilene, TX Metro Area
# 1    Akron, OH Metro Area
#
#    Estimate; Less than high school graduate: - In labor force:  \
# 0                                               6484
# 1                                              14519
#
#    Estimate; Less than high school graduate: - In labor force: - In Armed Forces  \
# 0                                                  0
# 1                                                  0
#
#    Estimate; Less than high school graduate: - In labor force: - Civilian:  \
# 0                                               6484
# 1                                              14519
#
#    Estimate; Less than high school graduate: - In labor force: - Civilian: - Employed  \
# 0                                               5347
# 1                                              11338
#
#    Estimate; Less than high school graduate: - In labor force: - Civilian: - Unemployed  \
# 0                                               1137
# 1                                               3181
#
#    Estimate; Less than high school graduate: - Not in labor force  \
# 0                                               7336
# 1                                              12094
#
#    Estimate; High school graduate: - In labor force:  \
# 0                                              16331
# 1                                              91228
#
#    Estimate; High school graduate: - In labor force: - In Armed Forces  \
# 0                                                242
# 1                                                  0
#
#    Estimate; High school graduate: - In labor force: - Civilian:  ...  \
# 0                                              16089              ...
# 1                                              91228              ...
#
#    Estimate; Some college or associate's degree: - In labor force: - Civilian:  \
# 0                                              19725
# 1                                              86871
#
#    Estimate; Some college or associate's degree: - In labor force: - Civilian: - Employed  \
# 0                                              18421
# 1                                              79172
#
#    Estimate; Some college or associate's degree: - In labor force: - Civilian: - Unemployed  \
# 0                                               1304
# 1                                               7699
#
#    Estimate; Some college or associate's degree: - Not in labor force  \
# 0                                               5839
# 1                                              24017
#
#    Estimate; Bachelor's degree or higher: - In labor force:  \
# 0                                              13488
# 1                                              97736
#
#    Estimate; Bachelor's degree or higher: - In labor force: - In Armed Forces  \
# 0                                                579
# 1                                                 43
#
#    Estimate; Bachelor's degree or higher: - In labor force: - Civilian:  \
# 0                                              12909
# 1                                              97693
#
#    Estimate; Bachelor's degree or higher: - In labor force: - Civilian: - Employed  \
# 0                                              12770
# 1                                              94492
#
#    Estimate; Bachelor's degree or higher: - In labor force: - Civilian: - Unemployed  \
# 0                                                139
# 1                                               3201
#
#    Estimate; Bachelor's degree or higher: - Not in labor force
# 0                                               3633
# 1                                              13895
#
# [2 rows x 25 columns]

# %%
# Testing Cell
assert df_j3.shape == (152, 25)
assert df_j3.index.name == None
assert "Estimate; Less than high school graduate: - In labor force: - Civilian: - Unemployed" in df_j3
assert "Estimate; Bachelor's degree or higher: - In labor force:" in df_j3
assert "Battle Creek, MI Metro Area" not in list(df_j3.Geography)
assert "Bridgeport-Stamford-Norwalk, CT Metro Area" not in list(df_j3.Geography)
assert "Asheville, NC Metro Area" in list(df_j3.Geography)
assert df_j3.iloc[5,7] == 38994
assert df_j3.iloc[5,15] == 59784

# %% [markdown]
# **Q9:** Explain the difference in the number of rows and columns in `df_j1`, `df_j2`, and `df_j3`.  Be specific.

# %% [markdown]
# df_j1 is a left join data frame with 249 rows and 24 columns. The left data drame was from education_left_orig, so the 249 rows match with the 249 observations from education_left_orig, plus the original 12 columns from education_left_orig and new 12 columns from education_right_j. The 12 new columns will have values (or NaNs) for each row in the education_left_orig index variable "Geography".
#
# df_j2 is an innter join data frame with 152 rows and 24 columns. This 152 rows are the common values in the indexed "Geography" that appear in both education_left_orig and education_right_j. Then, it pulls all the according values from all columns in both of the data frames to df_j2. df_j2 should not have any NaN values.
#
# df_j3 is a merge on "Geography" data frame with 152 rows and 25 columns. This data frame is almost identical as df_j2, but it has "Geography" as a data frame column, not index.

# %% [markdown]
# ---
#
# ---
#
# ## Part D
#
# **Q10:** How much time (in minutes/hours) did you spend on this homework assignment?

# %% [markdown]
# 40 minutes

# %% [markdown]
# **Q11:** Who was your partner for this assignment?  If you worked alone, say so instead.

# %% [markdown]
# Alone
